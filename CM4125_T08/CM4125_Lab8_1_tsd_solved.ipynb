# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosfmorenog/CM4125/blob/main/CM4125_T8/CM4125_Lab8_1_tsd_solved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CM4125 Topic 7 Lab Part 1 (TSD) Solved

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load the `ether.csv` data set into the variable `ether`
#
# - https://www.dropbox.com/scl/fi/v140wcj9yh06lu3k7e2sr/ether.csv?rlkey=kcoddlrxywu7raeo2oi1rsi7l&raw=1

# %% [markdown]
# using column `0` (`'Date'`) as the index, and parse this column as a date

# %%
ether = pd.read_csv('https://www.dropbox.com/scl/fi/v140wcj9yh06lu3k7e2sr/ether.csv?rlkey=kcoddlrxywu7raeo2oi1rsi7l&raw=1',
                    parse_dates=['Date'], index_col=0)
ether
# Out:
#                        Open    High     Low   Close    Volume
# Date
# 2020-03-13 20:00:00  129.94  131.82  126.87  128.71  14952.18
# 2020-03-13 19:00:00  119.51  132.02  117.10  129.94  60675.35
# 2020-03-13 18:00:00  124.47  124.85  115.50  119.51  40771.21
# 2020-03-13 17:00:00  124.08  127.42  121.63  124.47  22119.04
# 2020-03-13 16:00:00  124.85  129.51  120.17  124.08  35884.55
# ...                     ...     ...     ...     ...       ...
# 2017-07-01 15:00:00  265.74  272.74  265.00  272.57   5581.66
# 2017-07-01 14:00:00  268.79  269.90  265.00  265.74   6367.05
# 2017-07-01 13:00:00  274.83  274.93  265.00  268.79  11204.43
# 2017-07-01 12:00:00  275.01  275.01  271.00  274.83   3023.14
# 2017-07-01 11:00:00  279.98  279.99  272.10  275.01   2455.28
#
# [23674 rows x 5 columns]

# %% [markdown]
# Check that the index column is a data type (i.e. `Timestamp`), and not a string

# %%
print(ether.index[0])
print(type(ether.index[0]))
# Out:
# 2020-03-13 20:00:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# The data in this dataset is sorted descending by date

# %% [markdown]
# Re-sort the data ascending by index

# %% [markdown]
# **Q. When did this data set begin?**

# %%
ether.sort_index(inplace=True)
ether
# Out:
#                        Open    High     Low   Close    Volume
# Date
# 2017-07-01 11:00:00  279.98  279.99  272.10  275.01   2455.28
# 2017-07-01 12:00:00  275.01  275.01  271.00  274.83   3023.14
# 2017-07-01 13:00:00  274.83  274.93  265.00  268.79  11204.43
# 2017-07-01 14:00:00  268.79  269.90  265.00  265.74   6367.05
# 2017-07-01 15:00:00  265.74  272.74  265.00  272.57   5581.66
# ...                     ...     ...     ...     ...       ...
# 2020-03-13 16:00:00  124.85  129.51  120.17  124.08  35884.55
# 2020-03-13 17:00:00  124.08  127.42  121.63  124.47  22119.04
# 2020-03-13 18:00:00  124.47  124.85  115.50  119.51  40771.21
# 2020-03-13 19:00:00  119.51  132.02  117.10  129.94  60675.35
# 2020-03-13 20:00:00  129.94  131.82  126.87  128.71  14952.18
#
# [23674 rows x 5 columns]

# %% [markdown]
# Answer: 2017-07-01 at 11 AM

# %% [markdown]
# The data set contains the following columns:
#
# Price Data:
#
# - Open - The price of the commodity *(ether)* at the **start** of the time period *(minute)*
# - High - The **highest** value the price reached during the time period
# - Low - The **lowest** value the price reached during the time period
# - Close - The price at the **end** of the time period
#
# Trade Data:
#
# - Volume - The total amount of the commodity bought/sold in the time period

# %% [markdown]
# Re-sample the data on a *daily* basis (`'1D'`) into a variable called `daily_ether`

# %% [markdown]
# Apply the following aggregation functions:

# %% [markdown]
# | Column | Aggregation Function |
# | :----- | :------------------- |
# | Open   | `lambda x: x[0]`     |
# | High   | `np.max`             |
# | Low    | `np.min.`            |
# | Close  | `lambda x: x[-1]`    |
# | Volume | `np.sum`             |

# %%
import warnings
warnings.filterwarnings('ignore')
daily_ether = ether.resample('1D').apply({'Open'   : lambda x: x[0],
                                          'High'   : np.max,
                                          'Low'    : np.min,
                                          'Close'  : lambda x: x[-1],
                                          'Volume' : np.sum})
daily_ether
# Out:
#               Open    High     Low   Close      Volume
# Date
# 2017-07-01  279.98  279.99  253.23  263.12   108835.60
# 2017-07-02  263.12  293.73  255.70  285.00   189772.27
# 2017-07-03  285.00  285.00  273.07  276.37   125450.81
# 2017-07-04  276.37  282.83  265.00  269.20   109560.93
# 2017-07-05  269.20  274.97  252.67  266.27   163719.09
# ...            ...     ...     ...     ...         ...
# 2020-03-09  199.46  208.65  189.85  202.77   457449.62
# 2020-03-10  202.77  206.28  195.17  200.50   184956.96
# 2020-03-11  200.50  202.98  181.00  194.61   237607.68
# 2020-03-12  194.61  195.64  101.22  110.30  1271270.79
# 2020-03-13  110.30  148.00   90.00  128.71  1191586.11
#
# [987 rows x 5 columns]

# %% [markdown]
# Check that the `Close` price is the same as the `Open` price for the next week

# %% [markdown]
# Calculate the price half way between the `Low` and `High` for each day and store the result in a column named `Ether (ETH)`

# %%
daily_ether['Ether (ETH)'] = (daily_ether['Low'] + daily_ether['High']) / 2.0
daily_ether
# Out:
#               Open    High     Low   Close      Volume  Ether (ETH)
# Date
# 2017-07-01  279.98  279.99  253.23  263.12   108835.60      266.610
# 2017-07-02  263.12  293.73  255.70  285.00   189772.27      274.715
# 2017-07-03  285.00  285.00  273.07  276.37   125450.81      279.035
# 2017-07-04  276.37  282.83  265.00  269.20   109560.93      273.915
# 2017-07-05  269.20  274.97  252.67  266.27   163719.09      263.820
# ...            ...     ...     ...     ...         ...          ...
# 2020-03-09  199.46  208.65  189.85  202.77   457449.62      199.250
# 2020-03-10  202.77  206.28  195.17  200.50   184956.96      200.725
# 2020-03-11  200.50  202.98  181.00  194.61   237607.68      191.990
# 2020-03-12  194.61  195.64  101.22  110.30  1271270.79      148.430
# 2020-03-13  110.30  148.00   90.00  128.71  1191586.11      119.000
#
# [987 rows x 6 columns]

# %% [markdown]
# Remove all columns other than `Ether (ETH)`

# %% [markdown]
# Filter the data to include only data from December of 2017

# %% [markdown]
# You should have **31 row $\times$ 1 column** (plus the `Date` index)

# %% [markdown]
# Round the `Ether (ETH)` column to 2 decimal places

# %%
daily_ether = daily_ether[['Ether (ETH)']]
daily_ether = daily_ether[(daily_ether.index >= '2017-12') & (daily_ether.index < '2018-01')]
daily_ether = daily_ether.round(2)
daily_ether
# Out:
#             Ether (ETH)
# Date
# 2017-12-01       445.00
# 2017-12-02       463.08
# 2017-12-03       466.75
# 2017-12-04       461.20
# 2017-12-05       460.78
# 2017-12-06       443.50
# 2017-12-07       431.95
# 2017-12-08       449.56
# 2017-12-09       492.55
# 2017-12-10       462.06
# 2017-12-11       482.62
# 2017-12-12       607.56
# 2017-12-13       695.38
# 2017-12-14       709.42
# 2017-12-15       662.10
# 2017-12-16       709.58
# 2017-12-17       724.96
# 2017-12-18       746.90
# 2017-12-19       822.69
# 2017-12-20       767.30
# 2017-12-21       806.08
# 2017-12-22       629.98
# 2017-12-23       722.50
# 2017-12-24       688.00
# 2017-12-25       726.69
# 2017-12-26       754.54
# 2017-12-27       736.50
# 2017-12-28       709.17
# 2017-12-29       734.00
# 2017-12-30       720.00
# 2017-12-31       725.00

# %% [markdown]
# Load the data set `bitcoin_dec.csv` as `daily_bitcoin` (the first column is the index)
#
# - https://www.dropbox.com/scl/fi/3iscrnf26zkpbgiqmg202/bitcoin_dec.csv?rlkey=ct1bfwyblzh44g58wb8d1bpum&raw=1

# %%
daily_bitcoin = pd.read_csv('https://www.dropbox.com/scl/fi/3iscrnf26zkpbgiqmg202/bitcoin_dec.csv?rlkey=ct1bfwyblzh44g58wb8d1bpum&raw=1',
                    parse_dates=['Date'], index_col=0)
daily_bitcoin.index = pd.to_datetime(daily_bitcoin.index, format='%d/%m/%Y')
daily_bitcoin
# Out:
#             Bitcoin (BTC)
# Date
# 2017-12-01       10165.01
# 2017-12-02       10950.00
# 2017-12-03       11185.08
# 2017-12-04       11265.50
# 2017-12-05       11694.96
# 2017-12-06       12818.08
# 2017-12-07       15225.00
# 2017-12-08       15856.32
# 2017-12-09       15700.48
# 2017-12-10       14630.75
# 2017-12-11       16355.55
# 2017-12-12       16980.36
# 2017-12-13       16742.08
# 2017-12-14       16642.59
# 2017-12-15       17287.56
# 2017-12-16       18726.43
# 2017-12-17       19434.50
# 2017-12-18       18720.23
# 2017-12-19       17900.00
# 2017-12-20       16740.68
# 2017-12-21       16209.95
# 2017-12-22       13279.48
# 2017-12-23       14797.50
# 2017-12-24       14050.00
# 2017-12-25       14008.00
# 2017-12-26       15035.50
# 2017-12-27       15510.50
# 2017-12-28       14507.40
# 2017-12-29       14532.30
# 2017-12-30       13544.60
# 2017-12-31       13351.10

# %% [markdown]
# Join the two data sets to get a comparison of Ether (ETH) and Bitcoin (BTC) prices in December of 2017

# %% [markdown]
# Reset the index, so that the index become a named column

# %% [markdown]
# Store the result as the variable `december`

# %% [markdown]
# Here are the first few rows:
#
# |       |       Date | Bitcoin (BTC) | Ether (ETH) |
# | ----: | ---------: | ------------: | ----------: |
# | **0** | 2017-12-01 |      10165.01 |      445.00 |
# | **1** | 2017-12-02 |      10950.00 |      463.08 |
# | **2** | 2017-12-03 |      11185.08 |      466.75 |

# %%
december = daily_bitcoin.join(daily_ether)
december
# Out:
#             Bitcoin (BTC)  Ether (ETH)
# Date
# 2017-12-01       10165.01       445.00
# 2017-12-02       10950.00       463.08
# 2017-12-03       11185.08       466.75
# 2017-12-04       11265.50       461.20
# 2017-12-05       11694.96       460.78
# 2017-12-06       12818.08       443.50
# 2017-12-07       15225.00       431.95
# 2017-12-08       15856.32       449.56
# 2017-12-09       15700.48       492.55
# 2017-12-10       14630.75       462.06
# 2017-12-11       16355.55       482.62
# 2017-12-12       16980.36       607.56
# 2017-12-13       16742.08       695.38
# 2017-12-14       16642.59       709.42
# 2017-12-15       17287.56       662.10
# 2017-12-16       18726.43       709.58
# 2017-12-17       19434.50       724.96
# 2017-12-18       18720.23       746.90
# 2017-12-19       17900.00       822.69
# 2017-12-20       16740.68       767.30
# 2017-12-21       16209.95       806.08
# 2017-12-22       13279.48       629.98
# 2017-12-23       14797.50       722.50
# 2017-12-24       14050.00       688.00
# 2017-12-25       14008.00       726.69
# 2017-12-26       15035.50       754.54
# 2017-12-27       15510.50       736.50
# 2017-12-28       14507.40       709.17
# 2017-12-29       14532.30       734.00
# 2017-12-30       13544.60       720.00
# 2017-12-31       13351.10       725.00

# %% [markdown]
# Melt the data set to long format

# %% [markdown]
# The entity IDs are in the `Date` column

# %% [markdown]
# Set the var name to `'Commodity'` and value name to `'Price (USD)'`

# %% [markdown]
# You should have **62 rows $\times$ 3 columns**

# %%
december = december.reset_index()
december = december.melt(id_vars = ['Date'], var_name='Commodity',
                         value_name='Price (USD)')
december
# Out:
#          Date      Commodity  Price (USD)
# 0  2017-12-01  Bitcoin (BTC)     10165.01
# 1  2017-12-02  Bitcoin (BTC)     10950.00
# 2  2017-12-03  Bitcoin (BTC)     11185.08
# 3  2017-12-04  Bitcoin (BTC)     11265.50
# 4  2017-12-05  Bitcoin (BTC)     11694.96
# ..        ...            ...          ...
# 57 2017-12-27    Ether (ETH)       736.50
# 58 2017-12-28    Ether (ETH)       709.17
# 59 2017-12-29    Ether (ETH)       734.00
# 60 2017-12-30    Ether (ETH)       720.00
# 61 2017-12-31    Ether (ETH)       725.00
#
# [62 rows x 3 columns]

# %% [markdown]
# The code below will generate a semi-log plot of the price of Bitcoin and Ether in December 2017

# %%
import plotly.express as px
fig = px.line(december, x='Date', y='Price (USD)', color='Commodity', log_y=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="31077476-bc7e-4cdc-b67a-7ae65c211d9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31077476-bc7e-4cdc-b67a-7ae65c211d9c")) {                    Plotly.newPlot(                        "31077476-bc7e-4cdc-b67a-7ae65c211d9c",                        [{"hovertemplate":"Commodity=Bitcoin (BTC)\u003cbr\u003eDate=%{x}\u003cbr\u003ePrice (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bitcoin (BTC)","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bitcoin (BTC)","orientation":"v","showlegend":true,"x":["2017-12-01T00:00:00","2017-12-02T00:00:00","2017-12-03T00:00:00","2017-12-04T00:00:00","2017-12-05T00:00:00","2017-12-06T00:00:00","2017-12-07T00:00:00","2017-12-08T00:00:00","2017-12-09T00:00:00","2017-12-10T00:00:00","2017-12-11T00:00:00","2017-12-12T00:00:00","2017-12-13T00:00:00","2017-12-14T00:00:00","2017-12-15T00:00:00","2017-12-16T00:00:00","2017-12-17T00:00:00","2017-12-18T00:00:00","2017-12-19T00:00:00","2017-12-20T00:00:00","2017-12-21T00:00:00","2017-12-22T00:00:00","2017-12-23T00:00:00","2017-12-24T00:00:00","2017-12-25T00:00:00","2017-12-26T00:00:00","2017-12-27T00:00:00","2017-12-28T00:00:00","2017-12-29T00:00:00","2017-12-30T00:00:00","2017-12-31T00:00:00"],"xaxis":"x","y":[10165.01,10950.0,11185.08,11265.5,11694.96,12818.08,15225.0,15856.32,15700.48,14630.75,16355.55,16980.36,16742.08,16642.59,17287.56,18726.43,19434.5,18720.23,17900.0,16740.68,16209.95,13279.48,14797.5,14050.0,14008.0,15035.5,15510.5,14507.4,14532.3,13544.6,13351.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Commodity=Ether (ETH)\u003cbr\u003eDate=%{x}\u003cbr\u003ePrice (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ether (ETH)","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Ether (ETH)","orientation":"v","showlegend":true,"x":["2017-12-01T00:00:00","2017-12-02T00:00:00","2017-12-03T00:00:00","2017-12-04T00:00:00","2017-12-05T00:00:00","2017-12-06T00:00:00","2017-12-07T00:00:00","2017-12-08T00:00:00","2017-12-09T00:00:00","2017-12-10T00:00:00","2017-12-11T00:00:00","2017-12-12T00:00:00","2017-12-13T00:00:00","2017-12-14T00:00:00","2017-12-15T00:00:00","2017-12-16T00:00:00","2017-12-17T00:00:00","2017-12-18T00:00:00","2017-12-19T00:00:00","2017-12-20T00:00:00","2017-12-21T00:00:00","2017-12-22T00:00:00","2017-12-23T00:00:00","2017-12-24T00:00:00","2017-12-25T00:00:00","2017-12-26T00:00:00","2017-12-27T00:00:00","2017-12-28T00:00:00","2017-12-29T00:00:00","2017-12-30T00:00:00","2017-12-31T00:00:00"],"xaxis":"x","y":[445.0,463.08,466.75,461.2,460.78,443.5,431.95,449.56,492.55,462.06,482.62,607.56,695.38,709.42,662.1,709.58,724.96,746.9,822.69,767.3,806.08,629.98,722.5,688.0,726.69,754.54,736.5,709.17,734.0,720.0,725.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0 ...
