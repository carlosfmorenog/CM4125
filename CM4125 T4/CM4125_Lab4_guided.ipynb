# %% [markdown]
# # CM4125 Topic 4 Lab (Guided)

# %% [markdown]
# For this lab, we will be working with the dataset `films.csv`

# %% [markdown]
# Specify column $0$ as the index column

# %% [markdown]
# This column is the `imdb_id`, a unique identifier assigned by the Internet Movie Database (IMDB)

# %%
## This is not always the case in all data vis tools, some of them don't need an index!
# Out:
#            rank_afc_2007  rank_afc_1998  rank_wga_2005  rank_ss_2012  \
# imdb_id
# tt0000417            NaN            NaN            NaN           NaN
# tt0000439            NaN            NaN            NaN           NaN
# tt0006206            NaN            NaN            NaN           NaN
# tt0004972            NaN           44.0            NaN           NaN
# tt0006864           49.0            NaN            NaN           NaN
# ...                  ...            ...            ...           ...
# tt5895028            NaN            NaN            NaN           NaN
# tt5168192            NaN            NaN            NaN           NaN
# tt2543164            NaN            NaN            NaN           NaN
# tt2582782            NaN            NaN            NaN           NaN
# tt5663482            NaN            NaN            NaN           NaN
#
#           included_in_guardian_list included_in_1001_book  \
# imdb_id
# tt0000417                       NaN                  True
# ...

# %% [markdown]
# Show the first $3$ rows

# %%
## Most tools allow you to select the first/last n entries
# Out:
#            rank_afc_2007  rank_afc_1998  rank_wga_2005  rank_ss_2012  \
# imdb_id
# tt0000417            NaN            NaN            NaN           NaN
# tt0000439            NaN            NaN            NaN           NaN
# tt0006206            NaN            NaN            NaN           NaN
#
#           included_in_guardian_list included_in_1001_book  \
# imdb_id
# tt0000417                       NaN                  True
# tt0000439                       NaN                  True
# tt0006206                      True                  True
#
#                              title  year      rated   released  runtime  \
# imdb_id
# tt0000417       A Trip to the Moon  1902       TV-G   4-Oct-02       13
# tt0000439  The Great Train Robbery  1903       TV-G   1-Dec-03       11
# tt0006206             Les vampires  1915  NOT RATED  23-Nov-16      421
#
#                                genre          director           writer  \
# imdb_id
# ...

# %% [markdown]
# You should see that the index of these rows is `tt0000417`, `tt0000439`, and `tt0006206`

# %% [markdown]
# In this data set we will only be using a few columns:
#
# - `imdb_id` is the unique index of the film in the *Internet Movie DataBase*
# - `title` is the title of the film
# - `year` is the year the film was released
# - `imdb_votes` is the number of rating the film has received from users.

# %% [markdown]
# Get a random sampling of $5$ films to display

# %%
## Again, most tools will allow you to randomly select some samples
# Out:
#            rank_afc_2007  rank_afc_1998  rank_wga_2005  rank_ss_2012  \
# imdb_id
# tt1157605            NaN            NaN            NaN           NaN
# tt0073166            NaN            NaN            NaN           NaN
# tt0083658           97.0            NaN            NaN           NaN
# tt0048641            NaN            NaN            NaN           NaN
# tt0048434            NaN            NaN            NaN           NaN
#
#           included_in_guardian_list included_in_1001_book  \
# imdb_id
# tt1157605                       NaN                  True
# tt0073166                       NaN                  True
# tt0083658                      True                  True
# tt0048641                       NaN                  True
# tt0048434                       NaN                  True
#
#                                title  year      rated   released  runtime  \
# imdb_id
# tt1157605  Anvil: The Story of Anvil  2008    UNRATED  20-Feb-09       80
# ...

# %% [markdown]
# **Q. Which film has the index `tt0435761`?**

# %% [markdown]
# Answer:

# %% [markdown]
# Display a dataframe containing only films `tt0015361` and `tt0059817`

# %%
## Remember that you need to select entries based on a condition, in this case, the id being equal to these codes
# Out:
#            rank_afc_2007  rank_afc_1998  rank_wga_2005  rank_ss_2012  \
# imdb_id
# tt0015361            NaN            NaN            NaN           NaN
# tt0059817            NaN            NaN            NaN           NaN
#
#           included_in_guardian_list included_in_1001_book           title  \
# imdb_id
# tt0015361                       NaN                  True          Strike
# tt0059817                       NaN                  True  Tokyo Olympiad
#
#            year      rated   released  runtime               genre  \
# imdb_id
# tt0015361  1925  NOT RATED        NaN       82               Drama
# tt0059817  1965  NOT RATED  28-Jul-65       93  Documentary, Sport
#
#                        director  \
# imdb_id
# tt0015361  Sergei M. Eisenstein
# tt0059817          Kon Ichikawa
#
#                                                       writer  language  \
# imdb_id
# tt0015361  Grigori Aleksandrov, Sergei M. Eisenstein, Ily...       NaN
# ...

# %% [markdown]
# **Q. Which two films are these?**

# %% [markdown]
# Answer:

# %% [markdown]
# Display a dataframe containing only rows indexed $57$, $79$, and $190$

# %%
## Again, more conditions but now based on the original index which most tools would retain as well
# Out:
#            rank_afc_2007  rank_afc_1998  rank_wga_2005  rank_ss_2012  \
# imdb_id
# tt0022100            NaN            NaN            NaN           NaN
# tt0024028            NaN            NaN            NaN           NaN
# tt0038890            NaN            NaN            NaN           NaN
#
#           included_in_guardian_list included_in_1001_book             title  \
# imdb_id
# tt0022100                       NaN                  True                 M
# tt0024028                       NaN                  True  Footlight Parade
# tt0038890                      True                  True   Rome, Open City
#
#            year      rated   released  runtime                     genre  \
# imdb_id
# tt0022100  1931  NOT RATED  31-Aug-31       99     Crime, Drama, Mystery
# tt0024028  1933          G  21-Oct-33      104  Comedy, Musical, Romance
# tt0038890  1945   APPROVED  27-Sep-45      103      Drama, Thriller, War
#
#                      director  \
# imdb_id
# ...

# %% [markdown]
# Create a new dataframe containing all films in the data set where the `year` is $2000$ or later

# %%
## Creating a new dataframe is not always possible, yet filtering is!
# Out:
#            rank_afc_2007  rank_afc_1998  rank_wga_2005  rank_ss_2012  \
# imdb_id
# tt0172495            NaN            NaN            NaN           NaN
# tt0190332            NaN            NaN            NaN           NaN
# tt0190590            NaN            NaN            NaN           NaN
# tt0212338            NaN            NaN            NaN           NaN
# tt0168629            NaN            NaN            NaN           NaN
# ...                  ...            ...            ...           ...
# tt5895028            NaN            NaN            NaN           NaN
# tt5168192            NaN            NaN            NaN           NaN
# tt2543164            NaN            NaN            NaN           NaN
# tt2582782            NaN            NaN            NaN           NaN
# tt5663482            NaN            NaN            NaN           NaN
#
#           included_in_guardian_list included_in_1001_book  \
# imdb_id
# tt0172495                      True                  True
# ...

# %% [markdown]
# **Q. How many films from this data set are from $2000$ or later?**

# %% [markdown]
# Answer:

# %% [markdown]
# **Q. What is the median $50\%$ `runtime` of the films in the data set from the year $2000$ onwards?**

# %% [markdown]
# Answer:

# %% [markdown]
# **Q. What is the median `runtime` for films between the years $1990$ and $1999$ in the films data set?**

# %% [markdown]
# Answer:

# %% [markdown]
# Create a dataframe of 90's films, sorted by `title`

# %%
## Sorting is quite straightworward in Excel, but most tools allow data to be sorted based on a column
# Out:
#            rank_afc_2007  rank_afc_1998  rank_wga_2005  rank_ss_2012  \
# imdb_id
# tt0101985            NaN            NaN            NaN           NaN
# tt0104008            NaN            NaN            NaN           NaN
# tt0103634            NaN            NaN            NaN           NaN
# tt0099012            NaN            NaN            NaN           NaN
# tt0185125            NaN            NaN            NaN           NaN
# ...                  ...            ...            ...           ...
# tt0103130            NaN            NaN            NaN           NaN
# tt0114787            NaN            NaN            NaN           NaN
# tt0105695           68.0           98.0           30.0           NaN
# tt0111019            NaN            NaN            NaN           NaN
# tt0113557            NaN            NaN            NaN           NaN
#
#           included_in_guardian_list included_in_1001_book  \
# imdb_id
# tt0101985                       NaN                  True
# ...

# %% [markdown]
# Display the first $5$ items in this new dataframe

# %%
## Make sure the new dataset has been modified so that you can select the new top 5
# Out:
#            rank_afc_2007  rank_afc_1998  rank_wga_2005  rank_ss_2012  \
# imdb_id
# tt0101985            NaN            NaN            NaN           NaN
# tt0104008            NaN            NaN            NaN           NaN
# tt0103634            NaN            NaN            NaN           NaN
# tt0099012            NaN            NaN            NaN           NaN
# tt0185125            NaN            NaN            NaN           NaN
#
#           included_in_guardian_list included_in_1001_book  \
# imdb_id
# tt0101985                       NaN                  True
# tt0104008                       NaN                  True
# tt0103634                       NaN                  True
# tt0099012                       NaN                  True
# tt0185125                       NaN                  True
#
#                                                     title  year      rated  \
# imdb_id
# tt0101985                           A Brighter Summer Day  1991  NOT RATED
# ...

# %% [markdown]
# Show the 90's films sorted in **descending** order by `imbd_votes`, displaying only the first $10$

# %%
## Again, be sure you can sort in ascending/descending order
# Out:
#            rank_afc_2007  rank_afc_1998  rank_wga_2005  rank_ss_2012  \
# imdb_id
# tt0111161           72.0            NaN           22.0           NaN
# tt0137523            NaN            NaN            NaN           NaN
# tt0110912           94.0           95.0           16.0           NaN
# tt0109830           76.0           71.0           89.0           NaN
# tt0133093            NaN            NaN            NaN           NaN
# tt0114369            NaN            NaN            NaN           NaN
# tt0102926           74.0           65.0           61.0           NaN
# tt0120815           71.0            NaN            NaN           NaN
# tt0108052            8.0            9.0           49.0           NaN
# tt0169547            NaN            NaN           38.0           NaN
#
#           included_in_guardian_list included_in_1001_book  \
# imdb_id
# tt0111161                       NaN                  True
# tt0137523                       NaN                  True
# ...

# %% [markdown]
# You should see that the most voted film (The Shawshank Redemption) has $17110644$ votes

# %% [markdown]
# **Q. Which 90's film received the second-most votes?**

# %% [markdown]
# Answer:

# %% [markdown]
# **Q. Which 90's film received the twentieth-most votes?**

# %% [markdown]
# Answer:
