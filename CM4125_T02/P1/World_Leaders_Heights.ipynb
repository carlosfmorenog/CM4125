# %% [markdown]
# # Using Python and Wikidata to identify and compare the heights of various world leaders

# %% [markdown]
# Today's challenge consists on finding out who is the tallest from the following leaders:
#
#
# *   Robert Mugabe
# *   Vladimir Putin
# *   Vladimir Lenin
# *   Adolf Hitler
# *   Joseph Stalin

# %% [markdown]
# First, we import the library which we will use.
#
# You may need to run `pip install mkwikidata` first

# %%
# !pip install mkwikidata
# Out:
# Collecting mkwikidata
#   Downloading https://files.pythonhosted.org/packages/df/f4/76d912e03f037cb78f12eb694b3bb89ed19b4110a2b1d14cb9cbe6a0f777/mkwikidata-0.14-py2.py3-none-any.whl
# Collecting requests>=2.25.1 (from mkwikidata)
#   Downloading https://files.pythonhosted.org/packages/2d/61/08076519c80041bc0ffa1a8af0cbd3bf3e2b62af10435d269a9d0f40564d/requests-2.27.1-py2.py3-none-any.whl (63kB)
# Collecting charset-normalizer~=2.0.0; python_version >= "3" (from requests>=2.25.1->mkwikidata)
#   Downloading https://files.pythonhosted.org/packages/06/b3/24afc8868eba069a7f03650ac750a778862dc34941a4bebeb58706715726/charset_normalizer-2.0.12-py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests>=2.25.1->mkwikidata) (2019.11.28)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\anaconda\lib\site-packages (from requests>=2.25.1->mkwikidata) (2.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\anaconda\lib\site-packages (from requests>=2.25.1->mkwikidata) (1.24.3)
# Installing collected packages: charset-normalizer, requests, mkwikidata
#   Found existing installation: requests 2.21.0
#     Uninstalling requests-2.21.0:
#       Successfully uninstalled requests-2.21.0
# Successfully installed charset-normalizer-2.0.12 mkwikidata-0.14 requests-2.27.1

# %%
import mkwikidata

# %% [markdown]
# We have created and tested our world leader query in advance on the Wikidata Query interface and copied the SPARQL code below. See https://w.wiki/4ugN

# %%
query = """
SELECT DISTINCT ?leader ?leaderLabel ?height WHERE {
  VALUES ?o {
    wd:Q48352
    wd:Q2285706
  }
  # ?leader wdt:P21 wd:Q6581097;
    wdt:P39 ?position.
  # ?position wdt:P279 ?o.
  # ?leader wdt:P2048 ?height.
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
ORDER BY DESC (?height)
LIMIT 55
"""

# %% [markdown]
# Run the query

# %%
query_result = mkwikidata.run_query(query, params={ })

# %% [markdown]
# What does the query output?

# %%
query_result
# Out:
# {'head': {'vars': ['leader', 'leaderLabel', 'height']},
#  'results': {'bindings': [{'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q74660'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Peter Hussing'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '196'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3579995'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Édouard Philippe'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '194'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q19958436'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Octavian Morariu'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '193'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3384916'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Robert Busnel'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '192'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3167260'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Jean-Luc Rougé'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '190'}},
#    {'leader': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8007'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Franklin Delano Roosevelt'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '189'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q654177'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Carlos Roberto Flores'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '188'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3371352'},
#     'leaderLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Paul Goze'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '188'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q191060'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Manuel Zelaya'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '187'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2339085'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Zdravko Hebel'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '187'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q224766'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Manfred Deckert'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '186'}},
#    {'leader': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1316'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Saddam Hussein'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '186'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q57287'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Harald V of Norway'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '186'}},
#    {'leader': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q9960'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ronald Reagan'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '185'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q887322'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Rafael Leonardo Callejas Romero'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '185'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1322456'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Serge Blanco'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '185'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3168320'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Jean-Patrick Lescarboura'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '185'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q173139'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'George Weah'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '184'}},
#    {'leader': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q207'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'George W. Bush'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '183'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q941145'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Olivier Girault'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '183'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1340327'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Gilles Quénéhervé'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '183'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3379342'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Philippe Bernat-Salles'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '181'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q71312'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Josef Fendt'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '180'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1282611'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Patrick Proisy'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '180'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1393551'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Makharbek Khadartsev'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '180'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q33866'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Theodore Roosevelt'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '179'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q532156'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Yordan Letchkov'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '178'}},
#    {'leader': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8612'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Andrew Johnson'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '178'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1781966'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Konrad Dobler'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '178'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q862049'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Josu Urrutia'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '176'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q37817514'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Nicola Selva'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '176'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q959311'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Errol Tobias'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '175'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q465161'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Patxi López'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '175'}},
#    {'leader': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q352'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Adolf Hitler'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '174'}},
#    {'leader': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8440'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Hugo Chávez'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '173'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q11891'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'James K. Polk'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '173'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16549371'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Gian Nicola Berti'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '172'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5951723'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Juan Orlando Hernández'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '171'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1333298'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Frank Beaurepaire'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '170'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q61053'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Olaf Scholz'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '170'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q10707'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Robert Mugabe'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '170'}},
#    {'leader': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q7747'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Vladimir Putin'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '170'}},
#    {'leader': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q4737'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Porfirio Lobo Sosa'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '169'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q296741'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Enrique Peña Nieto'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '169'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q11820'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Martin Van Buren'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '168'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q299442'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Roberto Micheletti'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '166'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q983623'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Mariano Haro'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '165'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q441393'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ricardo Maduro'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '165'}},
#    {'leader': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1394'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Vladimir Lenin'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '165'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q65126'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Gregor Gysi'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '164'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16169026'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Pere Aragonès i Garcia'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '163'}},
#    {'leader': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q855'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Joseph Stalin'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '163'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q23530'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Dmitry Medvedev'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '163'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q76156'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Bacharuddin Jusuf Habibie'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '162'}},
#    {'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q172083'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Omar Bongo'},
#     'height': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '151'}}]}}

# %% [markdown]
# What type of object do we have?

# %%
print(type(query_result))
# Out:
# <class 'dict'>

# %% [markdown]
# We can extract the data to a list

# %%
data = [{"name" : x["leaderLabel"]["value"], "height" : int(x["height"]["value"])} for x in query_result["results"]["bindings"]]

# %%
print (data)
# Out:
# [{'name': 'Peter Hussing', 'height': 196}, {'name': 'Édouard Philippe', 'height': 194}, {'name': 'Octavian Morariu', 'height': 193}, {'name': 'Robert Busnel', 'height': 192}, {'name': 'Jean-Luc Rougé', 'height': 190}, {'name': 'Franklin Delano Roosevelt', 'height': 189}, {'name': 'Carlos Roberto Flores', 'height': 188}, {'name': 'Paul Goze', 'height': 188}, {'name': 'Manuel Zelaya', 'height': 187}, {'name': 'Zdravko Hebel', 'height': 187}, {'name': 'Manfred Deckert', 'height': 186}, {'name': 'Saddam Hussein', 'height': 186}, {'name': 'Harald V of Norway', 'height': 186}, {'name': 'Ronald Reagan', 'height': 185}, {'name': 'Rafael Leonardo Callejas Romero', 'height': 185}, {'name': 'Serge Blanco', 'height': 185}, {'name': 'Jean-Patrick Lescarboura', 'height': 185}, {'name': 'George Weah', 'height': 184}, {'name': 'George W. Bush', 'height': 183}, {'name': 'Olivier Girault', 'height': 183}, {'name': 'Gilles Quénéhervé', 'height': 183}, {'name': 'Philippe Bernat-Salles', 'height': 181}, {'name': 'Josef Fendt', 'height': 180}, {'name': 'Patrick Proisy', 'height': 180}, {'name': 'Makharbek Khadartsev', 'height': 180}, {'name': 'Theodore Roosevelt', 'height': 179}, {'name': 'Yordan Letchkov', 'height': 178}, {'name': 'Andrew Johnson', 'height': 178}, {'name': 'Konrad Dobler', 'height': 178}, {'name': 'Josu Urrutia', 'height': 176}, {'name': 'Nicola Selva', 'height': 176}, {'name': 'Errol Tobias', 'height': 175}, {'name': 'Patxi López', 'height': 175}, {'name': 'Adolf Hitler', 'height': 174}, {'name': 'Hugo Chávez', 'height': 173}, {'name': 'James K. Polk', 'height': 173}, {'name': 'Gian Nicola Berti', 'height': 172}, {'name': 'Juan Orlando Hernández', 'height': 171}, {'name': 'Frank Beaurepaire', 'height': 170}, {'name': 'Olaf Scholz', 'height': 170}, {'name': 'Robert Mugabe', 'height': 170}, {'name': 'Vladimir Putin', 'height': 170}, {'name': 'Porfirio Lobo Sosa', 'height': 169}, {'name': 'Enrique Peña Nieto', 'height': 169}, {'name': 'Martin Van Buren', 'height': 168}, {'name': 'Roberto Micheletti', 'height': 166}, {'name': 'Mariano Haro', 'height': 165}, {'name': 'Ricardo Maduro', 'height': 165}, {'name': 'Vladimir Lenin', 'height': 165}, {'name': 'Gregor Gysi', 'height': 164}, {'name': 'Pere Aragonès i Garcia', 'height': 163}, {'name': 'Joseph Stalin', 'height': 163}, {'name': 'Dmitry Medvedev', 'height': 163}, {'name': 'Bacharuddin Jusuf Habibie', 'height': 162}, {'name': 'Omar Bongo', 'height': 151}]

# %% [markdown]
# If we want, we can stick the data in a data frame and plot it

# %%
import pandas as pd
pd.DataFrame(data).set_index("name").head(10).plot.barh().invert_yaxis()

# %% [markdown]
# And we can look at the full data frame

# %%
pd.DataFrame(data).set_index("name")
# Out:
#                                  height
# name
# Peter Hussing                       196
# Édouard Philippe                    194
# Octavian Morariu                    193
# Robert Busnel                       192
# Jean-Luc Rougé                      190
# Franklin Delano Roosevelt           189
# Carlos Roberto Flores               188
# Paul Goze                           188
# Manuel Zelaya                       187
# Zdravko Hebel                       187
# Manfred Deckert                     186
# Saddam Hussein                      186
# Harald V of Norway                  186
# Ronald Reagan                       185
# Rafael Leonardo Callejas Romero     185
# Serge Blanco                        185
# Jean-Patrick Lescarboura            185
# George Weah                         184
# George W. Bush                      183
# Olivier Girault                     183
# Gilles Quénéhervé                   183
# Philippe Bernat-Salles              181
# Josef Fendt                         180
# Patrick Proisy                      180
# Makharbek Khadartsev                180
# Theodore Roosevelt                  179
# Yordan Letchkov                     178
# Andrew Johnson                      178
# Konrad Dobler                       178
# Josu Urrutia                        176
# Nicola Selva                        176
# Errol Tobias                        175
# Patxi López                         175
# Adolf Hitler                        174
# Hugo Chávez                         173
# James K. Polk                       173
# Gian Nicola Berti                   172
# Juan Orlando Hernández              171
# Frank Beaurepaire                   170
# Olaf Scholz                         170
# Robert Mugabe                       170
# Vladimir Putin                      170
# Porfirio Lobo Sosa                  169
# Enrique Peña Nieto                  169
# Martin Van Buren                    168
# Roberto Micheletti                  166
# Mariano Haro                        165
# Ricardo Maduro                      165
# Vladimir Lenin                      165
# Gregor Gysi                         164
# Pere Aragonès i Garcia              163
# Joseph Stalin                       163
# Dmitry Medvedev                     163
# Bacharuddin Jusuf Habibie           162
# Omar Bongo                          151

# %% [markdown]
# ### But who is the tallest of the leaders listed in our challenge?
#
# Let's create a list of our `targets`

# %%
our_leaders = ['Robert Mugabe', 'Vladimir Putin','Vladimir Lenin', 'Adolf Hitler','Joseph Stalin']

# %% [markdown]
# Then we can iterate over our dictionary query results, looking to see if they are in our list. If they match, compare their height. Each time we find one who is taller update the name and height.

# %%
max_leader = ""
max_height = 0

for x in query_result["results"]["bindings"]:
    if x["leaderLabel"]["value"] in our_leaders:
        if int(x["height"]["value"]) > max_height:
            max_height = int(x["height"]["value"])
            max_leader = x["leaderLabel"]["value"]

# %% [markdown]
# Print out our result

# %%
print("The tallest leader is " + max_leader + ", who is "+ str(max_height) + "cm tall.")
# Out:
# The tallest leader is Adolf Hitler, who is 174cm tall.
